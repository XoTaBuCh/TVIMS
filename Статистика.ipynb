# %% [markdown]
# #  Статистика

# %% [markdown]
# **Условие**
#
# Имеются 3 файла. В каждом из них содержатся данные, которые необходимо исследовать.
#
# С помощью методов выравнивания статистических рядов подобрать теоретическое распределение. Проверить гипотезы о соответствии закона распределения имеющихся данных теоретическому. (Проверить стандартные распределения, которые использовались раньше: геометрическое, биномиальное, Пуассона, равномерное, нормальное, экспоненциальное).
#
# Выполнить статистическое исследование(построение графиков(ГИСТОГРАММА 100% - без нее сразу 0), точечных, интервальных оценок, p-value).
# Постарайтесь подойти творчески и сделать лабораторную красивой.
#
# В качестве теоретического можно использовать генератор случайных величин из стандартной библиотеки того языка программирования, на котором будет выполняться работа, если это необходимо.

# %% [markdown]
# **Требования к работе:**
#
# Реализовать все используемые методы (если будет использовано что-то из библиотек, то придется во время сдачи писать самому ручками, а время-то ограничено..).
#
# чистый код (по аналогии с предыдущим пунктом - в случае плохого кода придется переписывать во время сдачи)

# %% [markdown]
# **Пожелания к работе:**
#
# Использовать Python и Jupyter Notebook (https://jupyter.org/)
#
# Описание того, что вы делали

# %%
#основные библиотеки, которые понадобятся
import numpy as np
import utils

# %% [markdown]
# # Считывание данных

# %%
def input(file):
    print("-" * 25)
    print("Исходные данные: " + file)
    print("-" * 25)
    with open(file, 'r') as f:
        s = [float(i) for i in f.readline().split(',')]
        np.random.shuffle(s)
        s = s[0:1000]
        s.sort()
    return s

# %%
utils.Kolmagorov(input("set_1.csv.xls"))
# Out:
# -------------------------
# Исходные данные: set_1.csv.xls
# -------------------------
# Математическое ожидание -  3.49  Дисперсия -  10.109899999999998
#
# Доверительный интервал для M:
# (3.2929259229629633, ', ', 3.687074077037037)
# Доверительный интервал для D:
# 7.633971543007538 ,  12.585828456992457
# Равномерное распределение:
# Lambda -  10.580126788021179
# P-Value -  2.626238049533443e-100
# Экспоненциальное распределение:
# Lambda -  7.83070434809433
# P-Value -  1.689748884639492e-54
# Нормальное распределение:
# Lambda -  6.889710010309976
# P-Value -  3.714100718611114e-42
# Геометрическое распределение:
# Lambda -  0.6697660745047531
# P-Value -  0.7524316377954352
# Пуассоновское распределение:
# Lambda -  5.79643115130979
# P-Value -  7.058905251706812e-30
# Биномиальное распределение:
# Lambda -  5.811730059426779
# P-Value -  4.920396208642743e-30
# Наивероятнейшее распределение: для лямбда =  0.6697660745047531  --  Геометрическое

# %% [markdown]
# # Set 2

# %%
utils.Kolmagorov(input("set_2.csv.xls"))
# Out:
# -------------------------
# Исходные данные: set_2.csv.xls
# -------------------------
# Математическое ожидание -  18.252784675999965  Дисперсия -  10762.331471785703
#
# Доверительный интервал для M:
# (11.822810136236068, ', ', 24.682759215763863)
# Доверительный интервал для D:
# 8957.826396362203 ,  12566.836547209203
# Равномерное распределение:
# Lambda -  13.911898765484976
# P-Value -  1.0085093777314757e-176
# Экспоненциальное распределение:
# Lambda -  12.870470076885304
# P-Value -  3.194283691509849e-150
# Нормальное распределение:
# Lambda -  1.2833373368363943
# P-Value -  0.07219759502683398
# Геометрическое распределение:
# Lambda -  12.99696118329204
# P-Value -  2.611418905226363e-153
# Пуассоновское распределение:
# Lambda -  14.571687686875576
# P-Value -  8.107020048566718e-195
# Биномиальное распределение:
# Lambda -  14.594139902574888
# P-Value -  1.882652233244625e-195
# Наивероятнейшее распределение: для лямбда =  1.2833373368363943  --  Нормальное

# %% [markdown]
# # Set 3

# %%
utils.Kolmagorov(input("set_3.csv.xls"))
# Out:
# -------------------------
# Исходные данные: set_3.csv.xls
# -------------------------
# Математическое ожидание -  0.13279361599999995  Дисперсия -  0.02523927681137657
#
# Доверительный интервал для M:
# (0.12294682942779354, ', ', 0.14264040257220634)
# Доверительный интервал для D:
# 0.018903951003895966 ,  0.03157460261885718
# Равномерное распределение:
# Lambda -  10.972813252650667
# P-Value -  4.432780076902518e-108
# Экспоненциальное распределение:
# Lambda -  0.7597426620303434
# P-Value -  0.6020778870491346
# Нормальное распределение:
# Lambda -  6.312349489350804
# P-Value -  2.1264173236626643e-35
# Геометрическое распределение:
#
#
# Наивероятнейшее распределение: для лямбда =  0.7597426620303434  --  Экспоненциальное
